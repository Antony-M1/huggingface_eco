# %% [markdown]
# # README
#
# Here the client requirements
#
# Required 5+ years of experience as a Python Developer with a strong portfolio of projects.
#
# Core Development Skills:
# Proficiency in Python for software development.
# In-depth knowledge of Python libraries like `OpenCV`, `Numpy`, `Scipy`, `Pandas`, `NLTK`, `Scikit-learn`
# Experience in reading and manipulating different file types like `XML`, `JSON`, `CSV`
# Knowledge of building and integrating with RESTful services.
# Machine Learning (ML) & Artificial Intelligence (AI): Familiarity with ML and AI concepts and tools.
# Experience with OpenAI APIs for integrating AI-powered language models (e.g., GPT) into software applications
# Familiarity with prompt engineering techniques to optimize and customize model outputs for specific tasks.
# Strong understanding of data structures and object-oriented programming.
# Experience with SQL, NoSQL
#
# Role & Responsibilities
# Develop, test and maintain high-quality software using Python programming language, Ability to diagnose and resolve software issues effectively.

# %% [markdown]
# # Install Package

# %%
# %%capture
# !pip -qqq install nltk

# %% [markdown]
# # Import Package

# %%
import os
import pandas as pd

import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk import ne_chunk, pos_tag

# %% [markdown]
# # NLTK

# %% [markdown]
# ## Downloading NLTK Data
#
#
# The items you mentioned are all datasets and models provided by the NLTK library. Here's a breakdown of each:
#
# 1. **`punkt`**:
#    - **Type**: Tokenization model
#    - **Purpose**: It is used for sentence and word tokenization. It helps split a text into sentences or words by recognizing sentence boundaries.
#    - **Usage**: Loaded using `nltk.download('punkt')`.
#
# 2. **`averaged_perceptron_tagger`**:
#    - **Type**: Part-of-speech tagging model
#    - **Purpose**: This model is used to assign parts of speech (e.g., noun, verb, adjective) to each word in a sentence based on its context.
#    - **Usage**: Loaded using `nltk.download('averaged_perceptron_tagger')`.
#
# 3. **`wordnet`**:
#    - **Type**: Lexical database
#    - **Purpose**: WordNet is a large lexical database of English words that helps with synonyms, antonyms, definitions, and relations between words (like hyponyms and hypernyms).
#    - **Usage**: Loaded using `nltk.download('wordnet')`.
#
# ### Summary
#
# - **Python Packages**: NLTK itself is a Python package that provides tools and resources for NLP.
# - **Datasets and Models**: The `punkt`, `averaged_perceptron_tagger`, and `wordnet` are datasets and models included in the NLTK library that facilitate various NLP tasks.
#
# If you have further questions or need clarification on any specific topic, feel free to ask!

# %%
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download("wordnet")
nltk.download('omw-1.4')
nltk.download("stopwords")
nltk.download('maxent_ne_chunker')
nltk.download('words')
# Out:
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /usr/share/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /usr/share/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /usr/share/nltk_data...
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /usr/share/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to /usr/share/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %% [markdown]
# ## Tokenization

# %%
text = "Hello world! Welcome to NLTK. It's a great library for NLP."

# %%
# Sentence Tokenization
sentance_tokenize = sent_tokenize(text)
print(sentance_tokenize)
# Out:
# ['Hello world!', 'Welcome to NLTK.', "It's a great library for NLP."]

# %%
# Word Tokenization
word_tok = word_tokenize(text)
print(word_tok)
# Out:
# ['Hello', 'world', '!', 'Welcome', 'to', 'NLTK', '.', 'It', "'s", 'a', 'great', 'library', 'for', 'NLP', '.']

# %%
# Stop Words
stop_words = set(stopwords.words("english"))
filtered_words = [word for word in word_tok if word.lower() not in stop_words]
print("Words: ", len(word_tok), "Filtered: ", len(filtered_words))
# Out:
# Words:  15 Filtered:  11

# %% [markdown]
# **Stemming and Lemmatization**
#
# **Stemming :** *to stop something that is increasing or spreading.*
#
#
# **Lemmatization :**  the process of reducing the different forms of a word to one single form, for example, reducing `builds`, `building`, or `built` to the **lemma** `build`: Lemmatization is the process of grouping inflected forms together as a single base form.
#
# Stemming reduces a word to its root form, while lemmatization converts a word to its base form using a dictionary.
#
# ![image](https://studymachinelearning.com/wp-content/uploads/2019/09/stemmin_lemm_ex-1.png)
#
# <img src="https://cdn.botpenguin.com/assets/website/Stemming_53678d43bc.png" alt="Example Image" width="250" height="250">

# %% [markdown]
# ### Stemming

# %%
stemmer = PorterStemmer()
stemmed_words = [stemmer.stem(word) for word in filtered_words]

data = {
    "Filterd Words" : filtered_words,
    "Stemmed Words": stemmed_words
}

df = pd.DataFrame(data)

df.style.set_caption("Stemmer Info").set_properties(**{
    'background-color': 'lightblue',
    'color': 'black',
    'border-color': 'white'
})
# Out:
# <style type="text/css">
# #T_974d4_row0_col0, #T_974d4_row0_col1, #T_974d4_row1_col0, #T_974d4_row1_col1, #T_974d4_row2_col0, #T_974d4_row2_col1, #T_974d4_row3_col0, #T_974d4_row3_col1, #T_974d4_row4_col0, #T_974d4_row4_col1, #T_974d4_row5_col0, #T_974d4_row5_col1, #T_974d4_row6_col0, #T_974d4_row6_col1, #T_974d4_row7_col0, #T_974d4_row7_col1, #T_974d4_row8_col0, #T_974d4_row8_col1, #T_974d4_row9_col0, #T_974d4_row9_col1, #T_974d4_row10_col0, #T_974d4_row10_col1 {
#   background-color: lightblue;
#   color: black;
#   border-color: white;
# }
# </style>
# <table id="T_974d4">
#   <caption>Stemmer Info</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_974d4_level0_col0" class="col_heading level0 col0" >Filterd Words</th>
#       <th id="T_974d4_level0_col1" class="col_heading level0 col1" >Stemmed Words</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_974d4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_974d4_row0_col0" class="data row0 col0" >Hello</td>
#       <td id="T_974d4_row0_col1" class="data row0 col1" >hello</td>
#     </tr>
#     <tr>
#       <th id="T_974d4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_974d4_row1_col0" class="data row1 col0" >world</td>
#       <td id="T_974d4_row1_col1" class="data row1 col1" >world</td>
#     </tr>
#     <tr>
#       <th id="T_974d4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_974d4_row2_col0" class="data row2 col0" >!</td>
#       <td id="T_974d4_row2_col1" class="data row2 col1" >!</td>
#     </tr>
#     <tr>
#       <th id="T_974d4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_974d4_row3_col0" class="data row3 col0" >Welcome</td>
#       <td id="T_974d4_row3_col1" class="data row3 col1" >welcom</td>
#     </tr>
#     <tr>
#       <th id="T_974d4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_974d4_row4_col0" class="data row4 col0" >NLTK</td>
#       <td id="T_974d4_row4_col1" class="data row4 col1" >nltk</td>
#     </tr>
#     <tr>
#       <th id="T_974d4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_974d4_row5_col0" class="data row5 col0" >.</td>
#       <td id="T_974d4_row5_col1" class="data row5 col1" >.</td>
#     </tr>
#     <tr>
#       <th id="T_974d4_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_974d4_row6_col0" class="data row6 col0" >'s</td>
#       <td id="T_974d4_row6_col1" class="data row6 col1" >'s</td>
#     </tr>
#     <tr>
#       <th id="T_974d4_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_974d4_row7_col0" class="data row7 col0" >great</td>
#       <td id="T_974d4_row7_col1" class="data row7 col1" >great</td>
#     </tr>
#     <tr>
#       <th id="T_974d4_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_974d4_row8_col0" class="data row8 col0" >library</td>
#       <td id="T_974d4_row8_col1" class="data row8 col1" >librari</td>
#     </tr>
#     <tr>
#       <th id="T_974d4_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_974d4_row9_col0" class="data row9 col0" >NLP</td>
#       <td id="T_974d4_row9_col1" class="data row9 col1" >nlp</td>
#     </tr>
#     <tr>
#       <th id="T_974d4_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_974d4_row10_col0" class="data row10 col0" >.</td>
#       <td id="T_974d4_row10_col1" class="data row10 col1" >.</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Lemmatization

# %%
try:
    lemmatizer = WordNetLemmatizer()
    lemmatized_words = [lemmatizer.lemmatize(word) for word in filtered_words]
except LookupError:
    # !mkdir nltk_data
    nltk.download("wordnet", "/kaggle/working/nltk_data")
    nltk.data.path.append('/kaggle/working/nltk_data')
    # !cd /kaggle/working/nltk_data/corpora && unzip wordnet.zip
finally:
    lemmatizer = WordNetLemmatizer()
    lemmatized_words = [lemmatizer.lemmatize(word) for word in filtered_words]
    
data = {
    "Filtered Words": filtered_words,
    "Lemmatized Words": lemmatized_words
}
df = pd.DataFrame(data)
df.style.set_caption("Lemmatization Info").set_properties(**{
    'background-color': 'lightblue',
    'color': 'black',
    'border-color': 'white'
})
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /kaggle/working/nltk_data...
# Archive:  wordnet.zip
#    creating: wordnet/
#   inflating: wordnet/lexnames
#   inflating: wordnet/data.verb
#   inflating: wordnet/index.adv
#   inflating: wordnet/adv.exc
#   inflating: wordnet/index.verb
#   inflating: wordnet/cntlist.rev
#   inflating: wordnet/data.adj
#   inflating: wordnet/index.adj
#   inflating: wordnet/LICENSE
#   inflating: wordnet/citation.bib
#   inflating: wordnet/noun.exc
#   inflating: wordnet/verb.exc
#   inflating: wordnet/README
#   inflating: wordnet/index.sense
#   inflating: wordnet/data.noun
#   inflating: wordnet/data.adv
#   inflating: wordnet/index.noun
#   inflating: wordnet/adj.exc
# <style type="text/css">
# #T_1f470_row0_col0, #T_1f470_row0_col1, #T_1f470_row1_col0, #T_1f470_row1_col1, #T_1f470_row2_col0, #T_1f470_row2_col1, #T_1f470_row3_col0, #T_1f470_row3_col1, #T_1f470_row4_col0, #T_1f470_row4_col1, #T_1f470_row5_col0, #T_1f470_row5_col1, #T_1f470_row6_col0, #T_1f470_row6_col1, #T_1f470_row7_col0, #T_1f470_row7_col1, #T_1f470_row8_col0, #T_1f470_row8_col1, #T_1f470_row9_col0, #T_1f470_row9_col1, #T_1f470_row10_col0, #T_1f470_row10_col1 {
#   background-color: lightblue;
#   color: black;
#   border-color: white;
# }
# </style>
# <table id="T_1f470">
#   <caption>Lemmatization Info</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1f470_level0_col0" class="col_heading level0 col0" >Filtered Words</th>
#       <th id="T_1f470_level0_col1" class="col_heading level0 col1" >Lemmatized Words</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1f470_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1f470_row0_col0" class="data row0 col0" >Hello</td>
#       <td id="T_1f470_row0_col1" class="data row0 col1" >Hello</td>
#     </tr>
#     <tr>
#       <th id="T_1f470_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1f470_row1_col0" class="data row1 col0" >world</td>
#       <td id="T_1f470_row1_col1" class="data row1 col1" >world</td>
#     </tr>
#     <tr>
#       <th id="T_1f470_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1f470_row2_col0" class="data row2 col0" >!</td>
#       <td id="T_1f470_row2_col1" class="data row2 col1" >!</td>
#     </tr>
#     <tr>
#       <th id="T_1f470_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1f470_row3_col0" class="data row3 col0" >Welcome</td>
#       <td id="T_1f470_row3_col1" class="data row3 col1" >Welcome</td>
#     </tr>
#     <tr>
#       <th id="T_1f470_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1f470_row4_col0" class="data row4 col0" >NLTK</td>
#       <td id="T_1f470_row4_col1" class="data row4 col1" >NLTK</td>
#     </tr>
#     <tr>
#       <th id="T_1f470_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1f470_row5_col0" class="data row5 col0" >.</td>
#       <td id="T_1f470_row5_col1" class="data row5 col1" >.</td>
#     </tr>
#     <tr>
#       <th id="T_1f470_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_1f470_row6_col0" class="data row6 col0" >'s</td>
#       <td id="T_1f470_row6_col1" class="data row6 col1" >'s</td>
#     </tr>
#     <tr>
#       <th id="T_1f470_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_1f470_row7_col0" class="data row7 col0" >great</td>
#       <td id="T_1f470_row7_col1" class="data row7 col1" >great</td>
#     </tr>
#     <tr>
#       <th id="T_1f470_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_1f470_row8_col0" class="data row8 col0" >library</td>
#       <td id="T_1f470_row8_col1" class="data row8 col1" >library</td>
#     </tr>
#     <tr>
#       <th id="T_1f470_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_1f470_row9_col0" class="data row9 col0" >NLP</td>
#       <td id="T_1f470_row9_col1" class="data row9 col1" >NLP</td>
#     </tr>
#     <tr>
#       <th id="T_1f470_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_1f470_row10_col0" class="data row10 col0" >.</td>
#       <td id="T_1f470_row10_col1" class="data row10 col1" >.</td>
#     </tr>
#   </tbody>
# </table>

# %%
lemmatizer = WordNetLemmatizer()
print(lemmatizer.lemmatize("feet"))
# Out:
# foot

# %% [markdown]
# ### Part-of-Speech Tagging
#
# ![image](https://cdn-media-1.freecodecamp.org/images/1*f6e0uf5PX17pTceYU4rbCA.jpeg)

# %%
pos_tags = nltk.pos_tag(filtered_words)

df = pd.DataFrame(pos_tags, columns=["Filtered Word", "POS Tag"])
df.style.set_caption("Lemmatization Info").set_properties(**{
    'background-color': 'lightblue',
    'color': 'black',
    'border-color': 'white'
})
# Out:
# <style type="text/css">
# #T_bd051_row0_col0, #T_bd051_row0_col1, #T_bd051_row1_col0, #T_bd051_row1_col1, #T_bd051_row2_col0, #T_bd051_row2_col1, #T_bd051_row3_col0, #T_bd051_row3_col1, #T_bd051_row4_col0, #T_bd051_row4_col1, #T_bd051_row5_col0, #T_bd051_row5_col1, #T_bd051_row6_col0, #T_bd051_row6_col1, #T_bd051_row7_col0, #T_bd051_row7_col1, #T_bd051_row8_col0, #T_bd051_row8_col1, #T_bd051_row9_col0, #T_bd051_row9_col1, #T_bd051_row10_col0, #T_bd051_row10_col1 {
#   background-color: lightblue;
#   color: black;
#   border-color: white;
# }
# </style>
# <table id="T_bd051">
#   <caption>Lemmatization Info</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bd051_level0_col0" class="col_heading level0 col0" >Filtered Word</th>
#       <th id="T_bd051_level0_col1" class="col_heading level0 col1" >POS Tag</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bd051_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bd051_row0_col0" class="data row0 col0" >Hello</td>
#       <td id="T_bd051_row0_col1" class="data row0 col1" >NNP</td>
#     </tr>
#     <tr>
#       <th id="T_bd051_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bd051_row1_col0" class="data row1 col0" >world</td>
#       <td id="T_bd051_row1_col1" class="data row1 col1" >NN</td>
#     </tr>
#     <tr>
#       <th id="T_bd051_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_bd051_row2_col0" class="data row2 col0" >!</td>
#       <td id="T_bd051_row2_col1" class="data row2 col1" >.</td>
#     </tr>
#     <tr>
#       <th id="T_bd051_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_bd051_row3_col0" class="data row3 col0" >Welcome</td>
#       <td id="T_bd051_row3_col1" class="data row3 col1" >JJ</td>
#     </tr>
#     <tr>
#       <th id="T_bd051_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_bd051_row4_col0" class="data row4 col0" >NLTK</td>
#       <td id="T_bd051_row4_col1" class="data row4 col1" >NNP</td>
#     </tr>
#     <tr>
#       <th id="T_bd051_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_bd051_row5_col0" class="data row5 col0" >.</td>
#       <td id="T_bd051_row5_col1" class="data row5 col1" >.</td>
#     </tr>
#     <tr>
#       <th id="T_bd051_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_bd051_row6_col0" class="data row6 col0" >'s</td>
#       <td id="T_bd051_row6_col1" class="data row6 col1" >POS</td>
#     </tr>
#     <tr>
#       <th id="T_bd051_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_bd051_row7_col0" class="data row7 col0" >great</td>
#       <td id="T_bd051_row7_col1" class="data row7 col1" >JJ</td>
#     </tr>
#     <tr>
#       <th id="T_bd051_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_bd051_row8_col0" class="data row8 col0" >library</td>
#       <td id="T_bd051_row8_col1" class="data row8 col1" >JJ</td>
#     </tr>
#     <tr>
#       <th id="T_bd051_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_bd051_row9_col0" class="data row9 col0" >NLP</td>
#       <td id="T_bd051_row9_col1" class="data row9 col1" >NNP</td>
#     </tr>
#     <tr>
#       <th id="T_bd051_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_bd051_row10_col0" class="data row10 col0" >.</td>
#       <td id="T_bd051_row10_col1" class="data row10 col1" >.</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Named Entity Recognition (NER)
#
# Named Entity Recognition (NER) is the process of identifying and classifying key entities in a text (like names of people, organizations, locations, etc.).

# %%
def named_entity_recognition(text:str):
    
    tokens = word_tokenize(text)
    pos_tags = pos_tag(tokens)
    named_entity = ne_chunk(pos_tags)
    return named_entity

# %%
text = "Barack Obama was born in Hawaii. He was the 44th President of the United States."
entities = named_entity_recognition(text)

print(entities)
# Out:
# (S
#   (PERSON Barack/NNP)
#   (PERSON Obama/NNP)
#   was/VBD
#   born/VBN
#   in/IN
#   (GPE Hawaii/NNP)
#   ./.
#   He/PRP
#   was/VBD
#   the/DT
#   44th/JJ
#   President/NNP
#   of/IN
#   the/DT
#   (GPE United/NNP States/NNPS)
#   ./.)
